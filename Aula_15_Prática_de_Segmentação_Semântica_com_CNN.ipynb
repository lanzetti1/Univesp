# %% [markdown]
# <a href="https://colab.research.google.com/github/lanzetti1/Univesp/blob/main/Aula_15_Pr%C3%A1tica_de_Segmenta%C3%A7%C3%A3o_Sem%C3%A2ntica_com_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COM530 - Visão Computacional
#
# ## Semana 5 - Segmentação
# ## Videoaula 15 - Prática de Segmentação Semântica com CNN
#
# - Importando os pacotes e imagens
# - Analisando as imagens
# - Preparando os dados
# - Construindo uma rede convolucional Unet
# - Treinando a rede
# - Avaliando os resultados
#
# Observações:
# - Ativar a GPU (Menu [Runtime], opção [Change runtime type])
# - Sem GPU, a execução deste caderno pode levar mais de 40 minutos.

# %% [markdown]
# #Importar os pacotes e carregar os dados.
#
# O conjunto de dados utilizado nesta aula foi construído a partir de imagens de Microscopia Eletrônica, as quais estão disponíveis em: https://www.epfl.ch/labs/cvlab/data/data-em/
#
# Essas imagens estão em alta-resolução e foram segmentadas em mitocôndrias e sinapses.
#
# A partir dessas imagens, foram geradas "sub-imagens" 256x256 a partir das regiões das imagens originais. Essas imagens 256x256 são as utilizadas nesta aula.

# %%
import os
import zipfile
import tensorflow as tf
from tensorflow.keras.utils import normalize
import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
import glob

# %% [markdown]
# #Carregando as imagens
#
# O conjunto de dados utilizado nesta aula foi construído a partir de imagens de Microscopia Eletrônica, as quais estão disponíveis em: https://www.epfl.ch/labs/cvlab/data/data-em/
#
# Essas imagens estão em alta-resolução e foram segmentadas em mitocôndrias e sinapses.
#
# A partir dessas imagens, foram geradas "sub-imagens" 256x256 a partir das regiões das imagens originais. Essas imagens 256x256 são as utilizadas nesta aula.

# %%
# !wget https://www.dropbox.com/s/rntsian2o49lzc5/256.zip?dl=1 -O 256.zip
# !mkdir -p tmp/mitochondria/

local_zip = '256.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('tmp/mitochondria/')
zip_ref.close()
# Out:
# --2023-04-26 21:09:21--  https://www.dropbox.com/s/rntsian2o49lzc5/256.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6020:18::a27d:4012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/rntsian2o49lzc5/256.zip [following]
# --2023-04-26 21:09:22--  https://www.dropbox.com/s/dl/rntsian2o49lzc5/256.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucad063691117428bbcc28d903e3.dl.dropboxusercontent.com/cd/0/get/B67Eh5t8ZKv4hjDxElJkErGC6xz0fviiXxqSnkNv63pu52cJQcJKy6IjTeFO_Ygw8W_9LCq853DfK1oze6N8NTd9AELb03GkBBccRd_7VA2iw11I198nM4YOxp1_bW_QOgCeXUHzq7xMHCeayfMgMx33YWUIXqp9JNc2qDj4T4UMYg/file?dl=1# [following]
# --2023-04-26 21:09:23--  https://ucad063691117428bbcc28d903e3.dl.dropboxusercontent.com/cd/0/get/B67Eh5t8ZKv4hjDxElJkErGC6xz0fviiXxqSnkNv63pu52cJQcJKy6IjTeFO_Ygw8W_9LCq853DfK1oze6N8NTd9AELb03GkBBccRd_7VA2iw11I198nM4YOxp1_bW_QOgCeXUHzq7xMHCeayfMgMx33YWUIXqp9JNc2qDj4T4UMYg/file?dl=1
# Resolving ucad063691117428bbcc28d903e3.dl.dropboxusercontent.com (ucad063691117428bbcc28d903e3.dl.dropboxusercontent.com)... 162.125.67.15, 2620:100:6031:15::a27d:510f
# Connecting to ucad063691117428bbcc28d903e3.dl.dropboxusercontent.com (ucad063691117428bbcc28d903e3.dl.dropboxusercontent.com)|162.125.67.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114565015 (109M) [application/binary]
# Saving to: ‘256.zip’
#
# 256.zip             100%[===================>] 109.26M  12.5MB/s    in 10s
#
# 2023-04-26 21:09:35 (10.9 MB/s) - ‘256.zip’ saved [114565015/114565015]

# %% [markdown]
# Especificar os diretórios das imagens e respectivas máscaras.

# %%
image_directory = 'tmp/mitochondria/256/images/'
mask_directory = 'tmp/mitochondria/256/masks/'

# %%
SIZE = 256
num_images = 500

# %% [markdown]
# Lendo as imagens.

# %%
image_names = glob.glob("tmp/mitochondria/256/images/*.tif")
print(image_names)
# Out:
# ['tmp/mitochondria/256/images/image_84_13.tif', 'tmp/mitochondria/256/images/image_17_03.tif', 'tmp/mitochondria/256/images/image_68_01.tif', 'tmp/mitochondria/256/images/image_161_21.tif', 'tmp/mitochondria/256/images/image_77_21.tif', 'tmp/mitochondria/256/images/image_52_01.tif', 'tmp/mitochondria/256/images/image_86_03.tif', 'tmp/mitochondria/256/images/image_128_13.tif', 'tmp/mitochondria/256/images/image_4_12.tif', 'tmp/mitochondria/256/images/image_0_00.tif', 'tmp/mitochondria/256/images/image_32_13.tif', 'tmp/mitochondria/256/images/image_105_21.tif', 'tmp/mitochondria/256/images/image_104_10.tif', 'tmp/mitochondria/256/images/image_115_02.tif', 'tmp/mitochondria/256/images/image_138_02.tif', 'tmp/mitochondria/256/images/image_22_00.tif', 'tmp/mitochondria/256/images/image_82_02.tif', 'tmp/mitochondria/256/images/image_107_01.tif', 'tmp/mitochondria/256/images/image_31_01.tif', 'tmp/mitochondria/256/images/image_100_13.tif', 'tmp/mitochondria/256/images/image_2_01.tif', 'tmp/mitochondria/256/images/image_40_03.tif', 'tmp/mitochondria/256/images/image_98_22.tif', 'tmp/mitochondria/256/images/image_135_21.tif', 'tmp/mitochondria/256/images/image_94_00.tif', 'tmp/mitochondria/256/images/image_130_00.tif', 'tmp/mitochondria/256/images/image_83_22.tif', 'tmp/mitochondria/256/images/image_89_13.tif', 'tmp/mitochondria/256/images/image_36_02.tif', 'tmp/mitochondria/256/images/image_22_23.tif', 'tmp/mitochondria/256/images/image_116_03.tif', 'tmp/mitochondria/256/images/image_82_20.tif', 'tmp/mitochondria/256/images/image_97_11.tif', 'tmp/mitochondria/256/images/image_129_22.tif', 'tmp/mitochondria/256/images/image_115_03.tif', 'tmp/mitochondria/256/images/image_16_12.tif', 'tmp/mitochondria/256/images/image_156_10.tif', 'tmp/mitochondria/256/images/image_40_23.tif', 'tmp/mitochondria/256/images/image_13_20.tif', 'tmp/mitochondria/256/images/image_145_01.tif', 'tmp/mitochondria/256/images/image_87_23.tif', 'tmp/mitochondria/256/images/image_14_23.tif', 'tmp/mitochondria/256/images/image_122_12.tif', 'tmp/mitochondria/256/images/image_39_13.tif', 'tmp/mitochondria/256/images/image_52_02.tif', 'tmp/mitochondria/256/images/image_1_12.tif', 'tmp/mitochondria/256/images/image_109_13.tif', 'tmp/mitochondria/256/images/image_94_12.tif', 'tmp/mitochondria/256/images/image_20_21.tif', 'tmp/mitochondria/256/images/image_35_12.tif', 'tmp/mitochondria/256/images/image_91_12.tif', 'tmp/mitochondria/256/images/image_123_13.tif', 'tmp/mitochondria/256/images/image_33_21.tif', 'tmp/mitochondria/256/images/image_61_23.tif', 'tmp/mitochondria/256/images/image_163_12.tif', 'tmp/mitochondria/256/images/image_136_10.tif', 'tmp/mitochondria/256/images/image_154_21.tif', 'tmp/mitochondria/256/images/image_110_21.tif', 'tmp/mitochondria/256/images/image_83_21.tif', 'tmp/mitochondria/256/images/image_17_23.tif', 'tmp/mitochondria/256/images/image_55_20.tif', 'tmp/mitochondria/256/images/image_44_02.tif', 'tmp/mitochondria/256/images/image_44_21.tif', 'tmp/mitochondria/256/images/image_134_23.tif', 'tmp/mitochondria/256/images/image_36_12.tif', 'tmp/mitochondria/256/images/image_148_03.tif', 'tmp/mitochondria/256/images/image_43_23.tif', 'tmp/mitochondria/256/images/image_11_03.tif', 'tmp/mitochondria/256/images/image_107_21.tif', 'tmp/mitochondria/256/images/image_102_11.tif', 'tmp/mitochondria/256/images/image_32_23.tif', 'tmp/mitochondria/256/images/image_97_22.tif', 'tmp/mitochondria/256/images/image_113_03.tif', 'tmp/mitochondria/256/images/image_3_12.tif', 'tmp/mitochondria/256/images/image_0_21.tif', 'tmp/mitochondria/256/images/image_127_03.tif', 'tmp/mitochondria/256/images/image_34_01.tif', 'tmp/mitochondria/256/images/image_16_23.tif', 'tmp/mitochondria/256/images/image_50_12.tif', 'tmp/mitochondria/256/images/image_139_01.tif', 'tmp/mitochondria/256/images/image_71_23.tif', 'tmp/mitochondria/256/images/image_46_10.tif', 'tmp/mitochondria/256/images/image_136_20.tif', 'tmp/mitochondria/256/images/image_159_10.tif', 'tmp/mitochondria/256/imag ...

# %%
image_names.sort()
print(image_names)
image_names_subset = image_names[0:num_images]
images = [cv2.imread(img, 0) for img in image_names_subset]
image_dataset = np.array(images)
image_dataset = np.expand_dims(image_dataset, axis = 3)
# Out:
# ['tmp/mitochondria/256/images/image_0_00.tif', 'tmp/mitochondria/256/images/image_0_01.tif', 'tmp/mitochondria/256/images/image_0_02.tif', 'tmp/mitochondria/256/images/image_0_03.tif', 'tmp/mitochondria/256/images/image_0_10.tif', 'tmp/mitochondria/256/images/image_0_11.tif', 'tmp/mitochondria/256/images/image_0_12.tif', 'tmp/mitochondria/256/images/image_0_13.tif', 'tmp/mitochondria/256/images/image_0_20.tif', 'tmp/mitochondria/256/images/image_0_21.tif', 'tmp/mitochondria/256/images/image_0_22.tif', 'tmp/mitochondria/256/images/image_0_23.tif', 'tmp/mitochondria/256/images/image_100_00.tif', 'tmp/mitochondria/256/images/image_100_01.tif', 'tmp/mitochondria/256/images/image_100_02.tif', 'tmp/mitochondria/256/images/image_100_03.tif', 'tmp/mitochondria/256/images/image_100_10.tif', 'tmp/mitochondria/256/images/image_100_11.tif', 'tmp/mitochondria/256/images/image_100_12.tif', 'tmp/mitochondria/256/images/image_100_13.tif', 'tmp/mitochondria/256/images/image_100_20.tif', 'tmp/mitochondria/256/images/image_100_21.tif', 'tmp/mitochondria/256/images/image_100_22.tif', 'tmp/mitochondria/256/images/image_100_23.tif', 'tmp/mitochondria/256/images/image_101_00.tif', 'tmp/mitochondria/256/images/image_101_01.tif', 'tmp/mitochondria/256/images/image_101_02.tif', 'tmp/mitochondria/256/images/image_101_03.tif', 'tmp/mitochondria/256/images/image_101_10.tif', 'tmp/mitochondria/256/images/image_101_11.tif', 'tmp/mitochondria/256/images/image_101_12.tif', 'tmp/mitochondria/256/images/image_101_13.tif', 'tmp/mitochondria/256/images/image_101_20.tif', 'tmp/mitochondria/256/images/image_101_21.tif', 'tmp/mitochondria/256/images/image_101_22.tif', 'tmp/mitochondria/256/images/image_101_23.tif', 'tmp/mitochondria/256/images/image_102_00.tif', 'tmp/mitochondria/256/images/image_102_01.tif', 'tmp/mitochondria/256/images/image_102_02.tif', 'tmp/mitochondria/256/images/image_102_03.tif', 'tmp/mitochondria/256/images/image_102_10.tif', 'tmp/mitochondria/256/images/image_102_11.tif', 'tmp/mitochondria/256/images/image_102_12.tif', 'tmp/mitochondria/256/images/image_102_13.tif', 'tmp/mitochondria/256/images/image_102_20.tif', 'tmp/mitochondria/256/images/image_102_21.tif', 'tmp/mitochondria/256/images/image_102_22.tif', 'tmp/mitochondria/256/images/image_102_23.tif', 'tmp/mitochondria/256/images/image_103_00.tif', 'tmp/mitochondria/256/images/image_103_01.tif', 'tmp/mitochondria/256/images/image_103_02.tif', 'tmp/mitochondria/256/images/image_103_03.tif', 'tmp/mitochondria/256/images/image_103_10.tif', 'tmp/mitochondria/256/images/image_103_11.tif', 'tmp/mitochondria/256/images/image_103_12.tif', 'tmp/mitochondria/256/images/image_103_13.tif', 'tmp/mitochondria/256/images/image_103_20.tif', 'tmp/mitochondria/256/images/image_103_21.tif', 'tmp/mitochondria/256/images/image_103_22.tif', 'tmp/mitochondria/256/images/image_103_23.tif', 'tmp/mitochondria/256/images/image_104_00.tif', 'tmp/mitochondria/256/images/image_104_01.tif', 'tmp/mitochondria/256/images/image_104_02.tif', 'tmp/mitochondria/256/images/image_104_03.tif', 'tmp/mitochondria/256/images/image_104_10.tif', 'tmp/mitochondria/256/images/image_104_11.tif', 'tmp/mitochondria/256/images/image_104_12.tif', 'tmp/mitochondria/256/images/image_104_13.tif', 'tmp/mitochondria/256/images/image_104_20.tif', 'tmp/mitochondria/256/images/image_104_21.tif', 'tmp/mitochondria/256/images/image_104_22.tif', 'tmp/mitochondria/256/images/image_104_23.tif', 'tmp/mitochondria/256/images/image_105_00.tif', 'tmp/mitochondria/256/images/image_105_01.tif', 'tmp/mitochondria/256/images/image_105_02.tif', 'tmp/mitochondria/256/images/image_105_03.tif', 'tmp/mitochondria/256/images/image_105_10.tif', 'tmp/mitochondria/256/images/image_105_11.tif', 'tmp/mitochondria/256/images/image_105_12.tif', 'tmp/mitochondria/256/images/image_105_13.tif', 'tmp/mitochondria/256/images/image_105_20.tif', 'tmp/mitochondria/256/images/image_105_21.tif', 'tmp/mitochondria/256/images/image_105_22.tif', 'tmp/mitochondria/256/images/image_105_ ...

# %% [markdown]
# Em seguida, ler as máscaras da mesma forma.

# %%
mask_names = glob.glob(mask_directory + "*.tif")
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask_dataset = np.array(masks)
mask_dataset = np.expand_dims(mask_dataset, axis = 3)

# %% [markdown]
# Algumas informações sobre as imagens.

# %%
print("Dimensões da imagem são: ", image_dataset.shape)
print("Dimensões das máscaras são: ", mask_dataset.shape)
print("Pixel máximo na imagem é: ", image_dataset.max())
print("Rótulos na imagem são: ", np.unique(mask_dataset))
# Out:
# Dimensões da imagem são:  (500, 256, 256, 1)
# Dimensões das máscaras são:  (500, 256, 256, 1)
# Pixel máximo na imagem é:  225
# Rótulos na imagem são:  [  0 255]

# %% [markdown]
# # Preparando os dados

# %% [markdown]
# Normalizando as imagens para o intervalo [0-,1].

# %%
# Normalizar as imagens
image_dataset = image_dataset /255.  # Também é possível normalizar ou escalar usando MinMax.
# Não normalizar as máscaras, apenas reescolar para valores entre 0 e 1.
mask_dataset = mask_dataset /255.  # Cada pixel terá valor entre 0 e 1.

# %% [markdown]
# Separando o conjunto de imagens em treino e teste.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.20, random_state = 42)

# %%
# Visualizar uma imagem aleatória e sua respectiva máscara.
import random

image_number = random.randint(0, len(X_train)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_train[image_number,:,:,0], cmap='gray')
plt.subplot(122)
plt.imshow(y_train[image_number,:,:,0], cmap='gray')
plt.show()

# %% [markdown]
# #Construindo uma rede convolucional Unet

# %%
# Gerar uma Unet dividindo o encoder do decoder em blocos

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate


def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)   # Não tem na rede original 
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)  # Não tem na rede original
    x = Activation("relu")(x)

    return x

# bloco Encoder: bloco Convolutional seguido por um Max pooling

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p   

# bloco Decoder
#  skip features gets input from encoder for concatenation

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# Construir uma rede Unet usando os blocos
def build_unet(input_shape, n_classes):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024) # Bridge

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    if n_classes == 1:  # Binária
      activation = 'sigmoid'
    else:
      activation = 'softmax'

    outputs = Conv2D(n_classes, 1, padding="same", activation=activation)(d4)  #Change the activation based on n_classes
    print(activation)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
IMG_HEIGHT = image_dataset.shape[1]
IMG_WIDTH  = image_dataset.shape[2]
IMG_CHANNELS = image_dataset.shape[3]

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
model = build_unet(input_shape, n_classes=1)
model.compile(optimizer=Adam(learning_rate = 1e-3), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# sigmoid
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,054,145
# Trainable params: 31,042,369
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# Visualização gráfica do modelo (rede Unet).

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# #Treinando a rede

# %%
history = model.fit(X_train, y_train, 
                    batch_size = 16, 
                    verbose=1, 
                    epochs=25, 
                    validation_data=(X_test, y_test), 
                    shuffle=False)
# Out:
# Epoch 1/25
# 25/25 [==============================] - 56s 1s/step - loss: 0.3345 - accuracy: 0.8880 - val_loss: 15.4812 - val_accuracy: 0.3058
# Epoch 2/25
# 25/25 [==============================] - 21s 845ms/step - loss: 0.1300 - accuracy: 0.9687 - val_loss: 74.0075 - val_accuracy: 0.0450
# Epoch 3/25
# 25/25 [==============================] - 22s 896ms/step - loss: 0.0955 - accuracy: 0.9759 - val_loss: 23.0022 - val_accuracy: 0.0452
# Epoch 4/25
# 25/25 [==============================] - 22s 901ms/step - loss: 0.0707 - accuracy: 0.9838 - val_loss: 1.2016 - val_accuracy: 0.4320
# Epoch 5/25
# 25/25 [==============================] - 23s 906ms/step - loss: 0.0536 - accuracy: 0.9890 - val_loss: 0.2026 - val_accuracy: 0.9493
# Epoch 6/25
# 25/25 [==============================] - 23s 914ms/step - loss: 0.0439 - accuracy: 0.9907 - val_loss: 0.3381 - val_accuracy: 0.9175
# Epoch 7/25
# 25/25 [==============================] - 23s 917ms/step - loss: 0.0357 - accuracy: 0.9927 - val_loss: 0.2557 - val_accuracy: 0.9278
# Epoch 8/25
# 25/25 [==============================] - 23s 923ms/step - loss: 0.0299 - accuracy: 0.9939 - val_loss: 0.2230 - val_accuracy: 0.9347
# Epoch 9/25
# 25/25 [==============================] - 22s 891ms/step - loss: 0.0250 - accuracy: 0.9949 - val_loss: 0.1689 - val_accuracy: 0.9550
# Epoch 10/25
# 25/25 [==============================] - 22s 899ms/step - loss: 0.0247 - accuracy: 0.9942 - val_loss: 4.8612 - val_accuracy: 0.3099
# Epoch 11/25
# 25/25 [==============================] - 23s 935ms/step - loss: 0.0228 - accuracy: 0.9942 - val_loss: 6.2896 - val_accuracy: 0.3883
# Epoch 12/25
# 25/25 [==============================] - 22s 895ms/step - loss: 0.0217 - accuracy: 0.9943 - val_loss: 1.5589 - val_accuracy: 0.6901
# Epoch 13/25
# 25/25 [==============================] - 23s 931ms/step - loss: 0.0186 - accuracy: 0.9952 - val_loss: 0.4446 - val_accuracy: 0.8943
# Epoch 14/25
# 25/25 [==============================] - 22s 896ms/step - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.2211 - val_accuracy: 0.9561
# Epoch 15/25
# 25/25 [==============================] - 23s 934ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.2068 - val_accuracy: 0.9576
# Epoch 16/25
# 25/25 [==============================] - 22s 900ms/step - loss: 0.0138 - accuracy: 0.9962 - val_loss: 0.2135 - val_accuracy: 0.9575
# Epoch 17/25
# 25/25 [==============================] - 23s 935ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.2107 - val_accuracy: 0.9580
# Epoch 18/25
# 25/25 [==============================] - 23s 931ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.2233 - val_accuracy: 0.9575
# Epoch 19/25
# 25/25 [==============================] - 23s 933ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.2233 - val_accuracy: 0.9577
# Epoch 20/25
# 25/25 [==============================] - 23s 939ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.2196 - val_accuracy: 0.9580
# Epoch 21/25
# 25/25 [==============================] - 22s 897ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.1804 - val_accuracy: 0.9621
# Epoch 22/25
# 25/25 [==============================] - 22s 896ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.2232 - val_accuracy: 0.9580
# Epoch 23/25
# 25/25 [==============================] - 23s 932ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.2272 - val_accuracy: 0.9589
# Epoch 24/25
# 25/25 [==============================] - 23s 930ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.1336 - val_accuracy: 0.9698
# Epoch 25/25
# 25/25 [==============================] - 23s 931ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.1620 - val_accuracy: 0.9665

# %% [markdown]
# Salvando a rede.

# %%
# Salva o modelo resultante (treinado) para podermos usá-lo posteriormente
model.save('tmp/mitochondria/saved_models/tutorial118_mitochondria_25epochs.hdf5')

# %% [markdown]
# #Avaliando os resultados

# %%
# "plotar" a acurácia e loss de treino e validação em cada época
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Loss do Treino')
plt.plot(epochs, val_loss, 'r', label='Loss da Validação')
plt.title('Loss de treino e validação')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Acurácia de treino')
plt.plot(epochs, val_acc, 'r', label='Acurácia de validação')
plt.title('Acurácia de treino e validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.legend()
plt.show()

# %%
# Carregar o modelo previamente gravado
from keras.models import load_model
model = load_model("tmp/mitochondria/saved_models/tutorial118_mitochondria_25epochs.hdf5", compile=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# IoU (Intersection over Union)
threshold = 0.5
y_pred = model.predict(X_test)
y_pred_thresholded = y_pred > threshold
# Out:
# 4/4 [==============================] - 17s 347ms/step

# %%
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_pred_thresholded, y_test)
print("Média IoU =", IOU_keras.result().numpy())

test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)
print(test_img_input.shape)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
print(prediction.shape)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Imagem de teste')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Rótulo de teste')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Predição da segmentação da imagem de teste')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# Média IoU = 0.60346085
# (1, 256, 256, 1)
# 1/1 [==============================] - 0s 20ms/step
# (256, 256)

# %% [markdown]
# #Agradecimento:
#
# Aula prática baseada no material disponibilizado em:
# https://youtu.be/oBIkr7CAE6g
